# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
url='C:/Users/LENOVO/jupyterNoteBook/laptop_pricing_dataset_mod1.csv'
data=pd.read_csv(url,header=0)
data.head(10)
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
# 5           5         Dell         3    Full HD    1   1         5
# 6           6           HP         3    Full HD    3   1         5
# 7           7         Acer         3  IPS Panel    2   1         5
# 8           8         Dell         3    Full HD    1   1         5
# 9           9         Acer         3  IPS Panel    3   1         7
#
#    Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0          35.560            1.6       8             256       1.60    978
# 1          39.624            2.0       4             256       2.20    634
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      238 non-null    int64
#  1   Manufacturer    238 non-null    object
#  2   Category        238 non-null    int64
#  3   Screen          238 non-null    object
#  4   GPU             238 non-null    int64
#  5   OS              238 non-null    int64
#  6   CPU_core        238 non-null    int64
#  7   Screen_Size_cm  234 non-null    float64
#  8   CPU_frequency   238 non-null    float64
#  9   RAM_GB          238 non-null    int64
#  10  Storage_GB_SSD  238 non-null    int64
#  11  Weight_kg       233 non-null    float64
#  12  Price           238 non-null    int64
# dtypes: float64(3), int64(8), object(2)
# memory usage: 24.3+ KB

# %%
data['Screen_Size_cm']=np.round(data[['Screen_Size_cm']],2)
data.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0           35.56            1.6       8             256       1.60    978
# 1           39.62            2.0       4             256       2.20    634
# 2           39.62            2.7       8             256       2.20    946
# 3           33.78            1.6       8             128       1.22   1244
# 4           39.62            1.8       8             256       1.91    837

# %%
data.replace('?',np.nan,inplace=True)
missed_data=data.isnull()
missed_data.head(10)
# Out:
#    Unnamed: 0  Manufacturer  Category  Screen    GPU     OS  CPU_core  \
# 0       False         False     False   False  False  False     False
# 1       False         False     False   False  False  False     False
# 2       False         False     False   False  False  False     False
# 3       False         False     False   False  False  False     False
# 4       False         False     False   False  False  False     False
# 5       False         False     False   False  False  False     False
# 6       False         False     False   False  False  False     False
# 7       False         False     False   False  False  False     False
# 8       False         False     False   False  False  False     False
# 9       False         False     False   False  False  False     False
#
#    Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0           False          False   False           False      False  False
# ...

# %%
for column in missed_data.columns.values.tolist():
    print(column)
    print(missed_data[column].value_counts())
    print("")
# Out:
# Unnamed: 0
# Unnamed: 0
# False    238
# Name: count, dtype: int64
#
# Manufacturer
# Manufacturer
# False    238
# Name: count, dtype: int64
#
# Category
# Category
# False    238
# Name: count, dtype: int64
#
# Screen
# Screen
# False    238
# Name: count, dtype: int64
#
# GPU
# GPU
# False    238
# Name: count, dtype: int64
#
# OS
# OS
# False    238
# Name: count, dtype: int64
#
# CPU_core
# CPU_core
# False    238
# Name: count, dtype: int64
#
# Screen_Size_cm
# Screen_Size_cm
# False    234
# True       4
# Name: count, dtype: int64
#
# CPU_frequency
# CPU_frequency
# False    238
# Name: count, dtype: int64
#
# RAM_GB
# RAM_GB
# False    238
# Name: count, dtype: int64
#
# Storage_GB_SSD
# Storage_GB_SSD
# False    238
# Name: count, dtype: int64
#
# Weight_kg
# Weight_kg
# False    233
# True       5
# Name: count, dtype: int64
#
# Price
# Price
# False    238
# Name: count, dtype: int64

# %%
avg_weight_kg=data['Weight_kg'].astype("float").mean(axis=0)
print('Average of weight-kg:',avg_weight_kg)
# Out:
# Average of weight-kg: 1.8622317596566522

# %%
data['Weight_kg'].replace(np.nan,avg_weight_kg,inplace=True)
data.head()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_20032\3071126237.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Weight_kg'].replace(np.nan,avg_weight_kg,inplace=True)
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# ...

# %%
data['Screen_Size_cm'].value_counts()
# Out:
# Screen_Size_cm
# 39.62    89
# 35.56    64
# 38.10    23
# 33.78    20
# 33.02    18
# 43.94     7
# 43.18     5
# 31.75     4
# 30.48     4
# Name: count, dtype: int64

# %%
max_Screen_Size=data['Screen_Size_cm'].value_counts().idxmax()
print(max_Screen_Size)
# Out:
# 39.62

# %%
data['Screen_Size_cm'].replace(np.nan,max_Screen_Size,inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_20032\2716882822.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Screen_Size_cm'].replace(np.nan,max_Screen_Size,inplace=True)

# %%
data.dtypes
# Out:
# Unnamed: 0          int64
# Manufacturer       object
# Category            int64
# Screen             object
# GPU                 int64
# OS                  int64
# CPU_core            int64
# Screen_Size_cm    float64
# CPU_frequency     float64
# RAM_GB              int64
# Storage_GB_SSD      int64
# Weight_kg         float64
# Price               int64
# dtype: object

# %%
data[['Screen_Size_cm']]=data[['Screen_Size_cm']].astype('float')
data[['Weight_kg']]=data[['Weight_kg']].astype('float')

# %%
data['Screen_Size_cm']=data['Screen_Size_cm']/2.54
data['Weight_kg']=data['Weight_kg']*2.205
data.rename(columns={'Weight_kg':'Weight_pounds'}, inplace=True)

data.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  Price
# 0       14.000000            1.6       8             256        3.52800    978
# 1       15.598425            2.0       4             256        4.85100    634
# 2       15.598425            2.7       8             256        4.85100    946
# 3       13.299213            1.6       8             128        2.69010   1244
# 4       15.598425            1.8       8             256        4.21155    837

# %%
data.rename(columns={'Screen_Size_cm':'Screen_Size_inch'},inplace=True)
data.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  \
# 0         14.000000            1.6       8             256        3.52800
# 1         15.598425            2.0       4             256        4.85100
# 2         15.598425            2.7       8             256        4.85100
# 3         13.299213            1.6       8             128        2.69010
# 4         15.598425            1.8       8             256        4.21155
#
#    Price
# 0    978
# 1    634
# 2    946
# 3   1244
# 4    837

# %%
data['CPU_frequency']=data['CPU_frequency']/data['CPU_frequency'].max()
data.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  \
# 0         14.000000       0.551724       8             256        3.52800
# 1         15.598425       0.689655       4             256        4.85100
# 2         15.598425       0.931034       8             256        4.85100
# 3         13.299213       0.551724       8             128        2.69010
# 4         15.598425       0.620690       8             256        4.21155
#
#    Price
# 0    978
# 1    634
# 2    946
# 3   1244
# 4    837

# %%
bins = np.linspace(min(data['Price']),max(data['Price']),4)
bins
# Out:
# array([ 527.        , 1621.33333333, 2715.66666667, 3810.        ])

# %%
Price_bins=['Low','Medium','High']
data['Price-binned']=pd.cut(data['Price'],bins,labels=Price_bins,include_lowest=True)
data[['Price','Price-binned']].tail()
# Out:
#      Price Price-binned
# 233   1891       Medium
# 234   1950       Medium
# 235   2236       Medium
# 236    883          Low
# 237   1499          Low

# %%
data['Price-binned'].value_counts()
# Out:
# Price-binned
# Low       160
# Medium     72
# High        6
# Name: count, dtype: int64

# %%
# %matplotlib inline
from matplotlib import pyplot
pyplot.bar(Price_bins,data['Price-binned'].value_counts())

plt.pyplot.xlabel("Price")
plt.pyplot.ylabel("Count")
plt.pyplot.title("Price-binned")
# Out:
# Text(0.5, 1.0, 'Price-binned')

# %%
dummy_variable_1=pd.get_dummies(data['Screen'])
dummy_variable_1.head()
# Out:
#    Full HD  IPS Panel
# 0    False       True
# 1     True      False
# 2     True      False
# 3    False       True
# 4     True      False

# %%
dummy_variable_1.rename(columns={'Full HD':'Full-HD-Screen','IPS Panel':'IPS-Panel-Screen'},inplace=True)
dummy_variable_1.head()
# Out:
#    Full-HD-Screen  IPS-Panel-Screen
# 0           False              True
# 1            True             False
# 2            True             False
# 3           False              True
# 4            True             False

# %%
data=pd.concat([data,dummy_variable_1],axis=1)
data.drop('Screen',axis=1,inplace=True)
data.head()
# Out:
#    Unnamed: 0 Manufacturer  Category  GPU  OS  CPU_core  Screen_Size_inch  \
# 0           0         Acer         4    2   1         5          2.170004
# 1           1         Dell         3    1   1         3          2.417761
# 2           2         Dell         3    1   1         7          2.417761
# 3           3         Dell         4    2   1         5          2.061382
# 4           4           HP         4    2   1         7          2.417761
#
#    CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  Price  \
# 0       0.551724       8             256           1.60    978
# 1       0.689655       4             256           2.20    634
# 2       0.931034       8             256           2.20    946
# 3       0.551724       8             128           1.22   1244
# 4       0.620690       8             256           1.91    837
#
#    Screen_Size_inch  Weight_pound Price-binned  Full-HD-Screen  \
# 0         14.000000      0.725624          Low           False
# ...
