# %%
import pandas as pd
import numpy as np

url = "C:/Users/LENOVO/Downloads/LaptopPrice/laptops.csv"
data = pd.read_csv(url)
data.head(10)
# Out:
#    Company                           Product   TypeName  Inches  \
# 0   Xiaomi                       Mi Notebook   Notebook    15.6
# 1   Xiaomi                       Mi Notebook  Ultrabook    13.3
# 2   Xiaomi                       Mi Notebook   Notebook    15.6
# 3   Xiaomi                       Mi Notebook  Ultrabook    13.3
# 4     Vero     K147 (N3350/4GB/32GB/FHD/W10)   Notebook    14.0
# 5     Vero         K146 (N3350/4GB/32GB/W10)   Notebook    14.0
# 6     Vero      V142 (X5-Z8350/2GB/32GB/W10)   Notebook    14.0
# 7     Vero  V131 (X5-Z8350/4GB/32GB/FHD/W10)   Notebook    13.3
# 8  Toshiba                     Satellite Pro   Notebook    15.6
# 9  Toshiba                     Satellite Pro   Notebook    15.6
#
#               ScreenResolution CPU_Company                 CPU_Type  \
# 0  IPS Panel Full HD 1920x1080       Intel            Core i5 8250U
# 1  IPS Panel Full HD 1920x1080       Intel            Core i5 7200U
# ...

# %%
data.columns
# Out:
# Index(['Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution',
#        'CPU_Company', 'CPU_Type', 'CPU_Frequency (GHz)', 'RAM (GB)', 'Memory',
#        'GPU_Company', 'GPU_Type', 'OpSys', 'Weight (kg)', 'Price (Euro)'],
#       dtype='object')

# %%
data.describe()
# Out:
#             Inches  CPU_Frequency (GHz)     RAM (GB)  Weight (kg)  \
# count  1275.000000          1275.000000  1275.000000  1275.000000
# mean     15.022902             2.302980     8.440784     2.040525
# std       1.429470             0.503846     5.097809     0.669196
# min      10.100000             0.900000     2.000000     0.690000
# 25%      14.000000             2.000000     4.000000     1.500000
# 50%      15.600000             2.500000     8.000000     2.040000
# 75%      15.600000             2.700000     8.000000     2.310000
# max      18.400000             3.600000    64.000000     4.700000
#
#        Price (Euro)
# count   1275.000000
# mean    1134.969059
# std      700.752504
# min      174.000000
# 25%      609.000000
# 50%      989.000000
# 75%     1496.500000
# max     6099.000000
