# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
url="C:/Users/LENOVO/Downloads/automobile/imports-85.data"
data=pd.read_csv(url,names=headers)
data.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %%
data.replace("?",np.nan,inplace=True) #replace "?" to NaN
data.head() #show the all rows
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
missed_data=data.isnull() #True for missing data
#also use .notnull() for not missing data
missed_data.head() #True for missing data
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0      False               True  False      False       False         False
# 1      False               True  False      False       False         False
# 2      False               True  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False              False  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0       False         False            False       False  ...        False
# 1       False         False            False       False  ...        False
# 2       False         False            False       False  ...        False
# 3       False         False            False       False  ...        False
# 4       False         False            False       False  ...        False
#
# ...

# %%
for column in missed_data.columns.values.tolist(): #count the missing data in each column
    print(column)
    print (missed_data[column].value_counts()) #count the missing data in each column
    print("")
# Out:
# symboling
# symboling
# False    205
# Name: count, dtype: int64
#
# normalized-losses
# normalized-losses
# False    164
# True      41
# Name: count, dtype: int64
#
# make
# make
# False    205
# Name: count, dtype: int64
#
# fuel-type
# fuel-type
# False    205
# Name: count, dtype: int64
#
# aspiration
# aspiration
# False    205
# Name: count, dtype: int64
#
# num-of-doors
# num-of-doors
# False    203
# True       2
# Name: count, dtype: int64
#
# body-style
# body-style
# False    205
# Name: count, dtype: int64
#
# drive-wheels
# drive-wheels
# False    205
# Name: count, dtype: int64
#
# engine-location
# engine-location
# False    205
# Name: count, dtype: int64
#
# wheel-base
# wheel-base
# False    205
# Name: count, dtype: int64
#
# length
# length
# False    205
# Name: count, dtype: int64
#
# width
# width
# False    205
# Name: count, dtype: int64
#
# height
# height
# False    205
# Name: count, dtype: int64
#
# curb-weight
# curb-weight
# False    205
# ...

# %%
avg_norm_losses = data["normalized-losses"].astype("float").mean(axis=0) #calculate the average of the column
print("Average of normalized-losses:", avg_norm_losses) #print the average of the column
# Out:
# Average of normalized-losses: 122.0

# %%
data["normalized-losses"].replace(np.nan, avg_norm_losses, inplace=True) #replace NaN by the average
data.head() #show the all rows
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_23520\934658590.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["normalized-losses"].replace(np.nan, avg_norm_losses, inplace=True) #replace NaN by the average
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romero       gas        std          two
# 1          3             122.0  alfa-romero       gas        std          two
# ...

# %%
avg_bore = data['bore'].astype('float').mean(axis=0) #calculate the average of the 
print("Average of bore:", avg_bore) #print the average of the column
# Out:
# Average of bore: 3.3297512437810943

# %%
data["bore"].replace(np.nan, avg_bore, inplace=True) #replace NaN by the average
data.head() #show the all rows
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_23520\2901379449.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["bore"].replace(np.nan, avg_bore, inplace=True) #replace NaN by the average
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romero       gas        std          two
# 1          3             122.0  alfa-romero       gas        std          two
# 2          1             122.0  alfa-romero       gas        std          two
# ...

# %%
avg_stroke = data['stroke'].astype('float').mean(axis=0) #calculate the average of the column
print("Average of stroke:", avg_stroke) #print the average of the column
# Out:
# Average of stroke: 3.255422885572139

# %%
data["stroke"].replace(np.nan, avg_stroke, inplace=True) #replace NaN by the average
data.head() #show the all rows
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_23520\27206094.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["stroke"].replace(np.nan, avg_stroke, inplace=True) #replace NaN by the average
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romero       gas        std          two
# 1          3             122.0  alfa-romero       gas        std          two
# 2          1             122.0  alfa-romero       gas        std          two
# ...

# %%
avg_horsepower = data['horsepower'].astype('float').mean(axis=0) #calculate the average of the column
print("Average horsepower:", avg_horsepower) #print the average of the column

data['horsepower'].replace(np.nan, avg_horsepower, inplace=True) #replace NaN by the average

avg_peakrpm = data['peak-rpm'].astype('float').mean(axis=0) #calculate the average of the column
print("Average peak rpm:", avg_peakrpm) #print the average of the column

data['peak-rpm'].replace(np.nan, avg_peakrpm, inplace=True) #replace NaN by the average
# Out:
# Average horsepower: 104.25615763546799
# Average peak rpm: 5125.369458128079
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_23520\1419696042.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['horsepower'].replace(np.nan, avg_horsepower, inplace=True) #replace NaN by the average
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_23520\1419696042.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
data['num-of-doors'].value_counts() #count the number of doors
# Out:
# num-of-doors
# four    114
# two      89
# Name: count, dtype: int64

# %%
data['num-of-doors'].value_counts().idxmax() #find the most common type of doors
# Out:
# 'four'

# %%
data["num-of-doors"].replace(np.nan, "four", inplace=True) #replace the missing 'num-of-doors' by the most common type of doors
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_23520\2165593295.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["num-of-doors"].replace(np.nan, "four", inplace=True) #replace the missing 'num-of-doors' by the most common type of doors

# %%
data.dropna(subset=["price"], axis=0, inplace=True) #drop the missing values of the column 'price', axis=0 means drop the entire row
data.reset_index(drop=True, inplace=True) #reset the index and drop the old index

# %%
data.head(25) #show the all rows
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3             122.0  alfa-romero       gas        std
# 1           3             122.0  alfa-romero       gas        std
# 2           1             122.0  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2             122.0         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1             122.0         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           2               192          bmw       gas        std
# 10          0               192          bmw       gas        std
# 11          0               188          bmw       gas        std
# 12          0               188          bmw       gas        std
# ...

# %%
data.dtypes #check the data type of each column
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
data[["bore", "stroke"]] = data[["bore", "stroke"]].astype("float")
data[["normalized-losses"]] = data[["normalized-losses"]].astype("int")
data[["price"]] = data[["price"]].astype("float")
data[["peak-rpm"]] = data[["peak-rpm"]].astype("float")

# %%
data.dtypes #check the data type of each column
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower            object
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
data['city-L/100km'] = 235/data['city-mpg'] #convert mpg to L/100km by mathematical operation (235 divided by mpg)
data.head() #show the all rows
#this is standardization
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# ...

# %%
data['highway-L/100km'] = 235/data['highway-mpg'] #convert mpg to L/100km by mathematical operation (235 divided by mpg)
data.head() #show the all rows
#this is standardization
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    bore  stroke  compression-ratio  horsepower peak-rpm city-mpg  highway-mpg  \
# ...

# %%
data['length'] = data['length']/data['length'].max() #normalize the column 'length'
data['width'] = data['width']/data['width'].max() #normalize the column 'width'
data['height'] = data['height']/data['height'].max() #normalize the column 'height'
data[["length","width","height"]].head() #show the all rows
# Out:
#      length     width    height
# 0  0.811148  0.890278  0.816054
# 1  0.811148  0.890278  0.816054
# 2  0.822681  0.909722  0.876254
# 3  0.848630  0.919444  0.908027
# 4  0.848630  0.922222  0.908027

# %%
data['horsepower'] = data['horsepower'].astype(int, copy=True) #convert data type to integer
# %matplotlib inline
from matplotlib import pyplot
plt.hist(data["horsepower"])
plt.xlabel("horsepower")
plt.ylabel("count")
plt.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
bins = np.linspace(min(data["horsepower"]), max(data["horsepower"]), 4) #create 3 bins of equal size bandwidth
bins
#linspace(start_value, end_value, numbers_generated) function returns an array with evenly spaced numbers over a specified interval.
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
group_names = ['Low', 'Medium', 'High']

# %%
data['horsepower-binned'] = pd.cut(data['horsepower'], bins, labels=group_names, include_lowest=True )
data[['horsepower','horsepower-binned']].head(20)
# Out:
#     horsepower horsepower-binned
# 0          111               Low
# 1          111               Low
# 2          154            Medium
# 3          102               Low
# 4          115               Low
# 5          110               Low
# 6          110               Low
# 7          110               Low
# 8          140            Medium
# 9          101               Low
# 10         101               Low
# 11         121            Medium
# 12         121            Medium
# 13         121            Medium
# 14         182            Medium
# 15         182            Medium
# 16         182            Medium
# 17          48               Low
# 18          70               Low
# 19          70               Low

# %%
data["horsepower-binned"].value_counts() #count the number of vehicles in each bin
# Out:
# horsepower-binned
# Low       153
# Medium     43
# High        5
# Name: count, dtype: int64

# %%
# %matplotlib inline
from matplotlib import pyplot
pyplot.bar(group_names, data["horsepower-binned"].value_counts())

plt.xlabel("horsepower")
plt.ylabel("count")
plt.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
# %matplotlib inline
# from matplotlib import pyplot

plt.hist(data["horsepower"], bins = 3)

plt.xlabel("horsepower")
plt.ylabel("count")
plt.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
dummy_variable_1 = pd.get_dummies(data["fuel-type"]) #convert categorical variable to dummy/indicator variables
dummy_variable_1.head()
# Out:
#    diesel   gas
# 0   False  True
# 1   False  True
# 2   False  True
# 3   False  True
# 4   False  True

# %%
dummy_variable_1.rename(columns={'gas':'fuel-type-gas', 'diesel':'fuel-type-diesel'}, inplace=True) #change column names
dummy_variable_1.head()
# Out:
#    fuel-type-diesel  fuel-type-gas
# 0             False           True
# 1             False           True
# 2             False           True
# 3             False           True
# 4             False           True

# %%
data=pd.concat([data,dummy_variable_1],axis=1) #merge data frame "data" and "dummy_variable_1"
data.drop("fuel-type", axis = 1, inplace=True) #drop original column "fuel-type" from "data"
data.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    horsepower  peak-rpm  city-mpg highway-mpg    price  city-L/100km  \
# ...

# %%
dummy_variable_2=pd.get_dummies(data['aspiration'])
dummy_variable_2.head()
# Out:
#     std  turbo
# 0  True  False
# 1  True  False
# 2  True  False
# 3  True  False
# 4  True  False

# %%
dummy_variable_2.rename(columns={'std':'aspiration-std','turbo':'aspiration-turbo'},inplace=True)
dummy_variable_2.head()
# Out:
#    aspiration-std  aspiration-turbo
# 0            True             False
# 1            True             False
# 2            True             False
# 3            True             False
# 4            True             False

# %%
data=pd.concat([data,dummy_variable_2],axis=1)
data.drop('aspiration',axis=1,inplace=True)
data.head(10)
# Out:
#    symboling  normalized-losses         make num-of-doors   body-style  \
# 0          3                122  alfa-romero          two  convertible
# 1          3                122  alfa-romero          two  convertible
# 2          1                122  alfa-romero          two    hatchback
# 3          2                164         audi         four        sedan
# 4          2                164         audi         four        sedan
# 5          2                122         audi          two        sedan
# 6          1                158         audi         four        sedan
# 7          1                122         audi         four        wagon
# 8          1                158         audi         four        sedan
# 9          2                192          bmw          two        sedan
#
#   drive-wheels engine-location  wheel-base    length     width  ...  city-mpg  \
# 0          rwd           front        88.6  0.811148  0.890278  ...        21
# ...

# %%
df_test = data[['drive-wheels','body-style','price']]
df_grp = df_test.groupby(['drive-wheels','body-style'],as_index=False).mean()
df_grp
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
df_pivot = df_grp.pivot(index='drive-wheels',columns='body-style')
df_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
plt.pcolor(df_pivot, cmap='RdBu')
plt.colorbar()
plt.show()

# %%
import seaborn as sns
sns.residplot(x=data['highway-mpg'],y= data['price'])
# Out:
# <Axes: xlabel='highway-mpg', ylabel='price'>

# %%
sns.regplot(x='highway-mpg',y='price',data=data)
# Out:
# <Axes: xlabel='highway-mpg', ylabel='price'>

# %%
sns.boxplot(x='drive-wheels',y='price',data=data)
# Out:
# <Axes: xlabel='drive-wheels', ylabel='price'>

# %%
import scipy.stats as scistats
pearson_coef,p_value=scistats.pearsonr(data['horsepower'],data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8096068016571054  with a P-value of P = 6.273536270650361e-48

# %%
# corr_matrix = data.corr()
# plt.figure(figsize=(20,10))
# sns.heatmap(corr_matrix,cmap="coolwarm" ,annot=True)

# plt.plot([0,len(corr_matrix)],[0,len(corr_matrix)],color='red',linewidth=3)
# plt.title('Correlation Matrix',fontsize=14)
# plt.show()

# %%
data['peak-rpm'].dtypes
# Out:
# dtype('float64')

# %%
numeric_data = data.select_dtypes(include=['float64','int64'])
numeric_data.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008153           0.055045    0.158018  0.123952
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075810           0.217300    0.371178  0.579795
# ...

# %%
data_corr=data[['bore','stroke','compression-ratio','horsepower']].corr()
data_corr
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566903
# stroke            -0.055390  1.000000           0.187871    0.098128
# compression-ratio  0.001263  0.187871           1.000000   -0.214489
# horsepower         0.566903  0.098128          -0.214489    1.000000

# %%
plt.pcolor(data_corr, cmap='RdBu')
plt.colorbar()
plt.show()

# %%
sns.regplot(x='engine-size',y='price',data=data)
plt.ylim(0,)
# Out:
# (0.0, 53349.17486383305)

# %%
data[['engine-size','price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
sns.regplot(x='highway-mpg',y='price',data=data)
# Out:
# <Axes: xlabel='highway-mpg', ylabel='price'>

# %%
data[['highway-mpg','price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %%
sns.regplot(x='peak-rpm',y='price',data=data)
# Out:
# <Axes: xlabel='peak-rpm', ylabel='price'>

# %%
data[['peak-rpm','price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %%
sns.regplot(x='stroke',y='price',data=data)
# Out:
# <Axes: xlabel='stroke', ylabel='price'>

# %%
data[['stroke','price']].corr()
# Out:
#           stroke     price
# stroke  1.000000  0.082269
# price   0.082269  1.000000

# %%
sns.boxplot(x='body-style',y='price',data=data)
# Out:
# <Axes: xlabel='body-style', ylabel='price'>

# %%
sns.boxplot(x='engine-location',y='price',data=data)
# Out:
# <Axes: xlabel='engine-location', ylabel='price'>

# %%
sns.boxplot(x='drive-wheels',y='price',data=data)
# Out:
# <Axes: xlabel='drive-wheels', ylabel='price'>

# %%
data.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  201.000000
# mean     0.899108  2555.666667   126.875622    3.330692    3.256874
# std      0.040933   517.296727    41.546834    0.268072    0.316048
# ...

# %%
data.describe(include=['object'])
# Out:
#           make num-of-doors body-style drive-wheels engine-location  \
# count      201          201        201          201             201
# unique      22            2          5            3               2
# top     toyota         four      sedan          fwd           front
# freq        32          115         94          118             198
#
#        engine-type num-of-cylinders fuel-system
# count          201              201         201
# unique           6                7           8
# top            ohc             four        mpfi
# freq           145              157          92

# %%
data['drive-wheels'].value_counts()
# Out:
# drive-wheels
# fwd    118
# rwd     75
# 4wd      8
# Name: count, dtype: int64

# %%
data['drive-wheels'].value_counts().to_frame()  #convert the series to a Dataframe
# Out:
#               count
# drive-wheels
# fwd             118
# rwd              75
# 4wd               8

# %%
drive_wheels_counts = data['drive-wheels'].value_counts().to_frame() #convert the series to a Dataframe
drive_wheels_counts.reset_index(inplace=True)
drive_wheels_counts=drive_wheels_counts.rename(columns={'drive-wheels':'value_counts'}) #rename the column
drive_wheels_counts
# Out:
#   value_counts  count
# 0          fwd    118
# 1          rwd     75
# 2          4wd      8

# %%
drive_wheels_counts.index.name='drive-wheels'
drive_wheels_counts
# Out:
#              value_counts  count
# drive-wheels
# 0                     fwd    118
# 1                     rwd     75
# 2                     4wd      8

# %%
engine_loc_counts = data['engine-location'].value_counts().to_frame()
engine_loc_counts.rename(columns={'engine-location':'value_counts'},inplace=True)
engine_loc_counts.index.name='engine-location'
engine_loc_counts.head(10)
# Out:
#                  count
# engine-location
# front              198
# rear                 3

# %%
data['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
data_group_one = data[['drive-wheels','body-style','price']]

# %%
data_grouped = data_group_one.groupby(['drive-wheels'],as_index=False).agg({'price':'mean'})
data_grouped
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %%
data_gptest = data[['drive-wheels','body-style','price']]
grouped_test1 = data_gptest.groupby(['drive-wheels','body-style'],as_index=False).mean()
grouped_test1
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
grouped_pivot = grouped_test1.pivot(index='drive-wheels',columns='body-style')
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
grouped_pivot = grouped_pivot.fillna(0) #fill missing values with 0
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
data_group_two = data[['body-style','price']]
data_grouped_two = data_group_two.groupby(['body-style'],as_index=False).mean()
data_grouped_two
# Out:
#     body-style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9957.441176
# 3        sedan  14459.755319
# 4        wagon  12371.960000

# %%
plt.pcolor(grouped_pivot, cmap='RdBu')
plt.colorbar()
plt.show()

# %%
fig, ax = plt.subplots()
im = ax.pcolor(grouped_pivot, cmap='RdBu')

#label names
row_labels = grouped_pivot.columns.levels[1]
col_labels = grouped_pivot.index

#move ticks and labels to the center
ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[0]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

#rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

# %%
data.select_dtypes(include=['number']).corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008153           0.055045    0.158018  0.123952
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075810           0.217300    0.371178  0.579795
# ...

# %%
from scipy import stats

# %%
# Calculate the Pearson Correlation Coefficient and P-value of 'wheel-base' and 'price'
peaeson_coef,p_value=stats.pearsonr(data['wheel-base'],data['price'])
print("The Pearson Correlation Coefficient is", peaeson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.5846418222655081  with a P-value of P = 8.076488270732847e-20

# %%
# Calculate the Pearson Correlation Coefficient and P-value of 'horsepower' and 'price'
pearson_coef,p_value=stats.pearsonr(data['horsepower'],data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8096068016571054  with a P-value of P = 6.273536270650361e-48

# %%
# Calculate the Pearson Correlation Coefficient and P-value of 'length' and 'price'
pearson_coef,p_value=stats.pearsonr(data['length'],data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.6906283804483642  with a P-value of P = 8.016477466158899e-30

# %%
# Calculate the Pearson Correlation Coefficient and P-value of 'width' and 'price'
pearson_coef,p_value=stats.pearsonr(data['width'],data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.7512653440522673  with a P-value of P = 9.200335510482136e-38

# %%
# Calculate the Pearson Correlation Coefficient and P-value of 'curb-weight' and 'price'
pearson_coef,p_value=stats.pearsonr(data['curb-weight'],data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8344145257702845  with a P-value of P = 2.189577238893924e-53

# %%
# Calculate the Pearson Correlation Coefficient and P-value of 'engine-size' and 'price'
pearson_coef,p_value=stats.pearsonr(data['engine-size'],data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8723351674455185  with a P-value of P = 9.26549162219869e-64

# %%
# Calculate the Pearson Correlation Coefficient and P-value of 'bore' and 'price'
pearson_coef,p_value=stats.pearsonr(data['bore'],data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.5431553832626603  with a P-value of P = 8.049189483935274e-17

# %%
# Calculate the Pearson Correlation Coefficient and P-value of 'city-mpg' and 'price'
pearson_coef,p_value=stats.pearsonr(data['city-mpg'],data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.6865710067844679  with a P-value of P = 2.3211320655675065e-29

# %%
# Calculate the Pearson Correlation Coefficient and P-value of 'highway-mpg' and 'price'
pearson_coef,p_value=stats.pearsonr(data['highway-mpg'],data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.7046922650589529  with a P-value of P = 1.7495471144476634e-31

# %%
data.to_csv('C:/Users/LENOVO/jupyterNoteBook/carNormalized.csv')
